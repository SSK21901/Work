# %%
pip install autocorrect
# Out:
# Collecting autocorrect
#   Downloading autocorrect-2.6.1.tar.gz (622 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.8/622.8 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py) ... done
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622363 sha256=867d25dd5267ea50b9d6ab99736d39ef9297e9335a633ac9d4b5e9101259e6cc
#   Stored in directory: /root/.cache/pip/wheels/b5/7b/6d/b76b29ce11ff8e2521c8c7dd0e5bfee4fb1789d76193124343
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1

# %%
from autocorrect import Speller
import random

# %%
import json
import random
import numpy as np
import nltk
import pickle
from autocorrect import Speller
from nltk.stem import WordNetLemmatizer
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.models import load_model

nltk.download("punkt")
nltk.download("wordnet")

# Lemmatizer
lemmatizer = WordNetLemmatizer()

# load intents
with open("/content/drive/MyDrive/Colab Notebooks/data.json") as file:
    intents = json.load(file)

try:  # load saved model if existed
    with open("data.pickle", "rb") as f:
        words, classes, training, output = pickle.load(f)
    model = load_model("chatbot-model8.h5")
except:  # create new model if not existed
    # create list of words, tags, and tuples (pattern+tag), and ignore words
    words = []
    classes = []
    documents = []
    ignore_words = ["?", "!", ".", ","]

    # loop through intents and patterns
    for intent in intents["intents"]:
        for pattern in intent["patterns"]:
            word_list = nltk.word_tokenize(pattern)  # tokenize each word
            words.extend(word_list)  # add to words list
            # add to patterns list
            documents.append(((word_list), intent["tag"]))

            if intent["tag"] not in classes:  # add to tags list if not already there
                classes.append(intent["tag"])

    words = [
        lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore_words
    ]  # lemmatize and lower each word
    # remove duplicates and sort
    words = sorted(set(words))
    classes = sorted(set(classes))

    # create training data
    training = []
    output = []
    out_empty = [0] * len(classes)  # empty list for output

    for document in documents:
        bag = []
        word_patterns = document[0]
        word_patterns = [
            lemmatizer.lemmatize(w.lower()) for w in word_patterns
        ]  # lemmatize each word

        for word in words:
            bag.append(1) if word in word_patterns else bag.append(0)
        output_row = list(out_empty)
        output_row[classes.index(document[1])] = 1
        training.append(bag)
        output.append(output_row)

    training = np.array(training)
    output = np.array(output)

    with open("data.pickle", "wb") as f:
        pickle.dump((words, classes, training, output), f)

    # create model (machine learning)
    model = Sequential()
    model.add(
        Dense(256, input_shape=(len(training[0]),), activation="relu")
    )  # input layer
    model.add(Dropout(0.4))  # dropout layer
    model.add(Dense(128, activation="relu"))  # hidden layer
    model.add(Dropout(0.4))  # dropout layer
    model.add(Dense(64, activation="relu"))  # hidden layer
    model.add(Dropout(0.4))  # dropout layer
    model.add(Dense(len(output[0]), activation="softmax"))  # output layer
    adam = Adam(learning_rate=0.001)  # optimizer
    model.compile(
        loss="categorical_crossentropy", optimizer=adam, metrics=["accuracy"]
    )  # compile model
    model.fit(
        training, output, epochs=300, batch_size=10, verbose=1
    )  # fit model (train)
    model.save("chatbot-model8.h5")  # save model
    print("Done")


# clean up message
def clean_up_message(message):
    message_word_list = nltk.word_tokenize(message)
    message_word_list = [
        lemmatizer.lemmatize(word.lower()) for word in message_word_list
    ]
    return message_word_list


# bag of words, 0 or 1 for each word in the bag that exists in the message
def bag_of_words(message, words):
    message_word = clean_up_message(message)
    bag = [0] * len(words)
    for w in message_word:
        for i, word in enumerate(words):
            if word == w:
                bag[i] = 1
    return np.array(bag)


# context
context = {}


# predict class, return list of tuples (tag, probability)
def predict_class(message, ERROR_THRESHOLD=0.25):
    bow = bag_of_words(message, words)
    res = model.predict(np.array([bow]))[0]
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append((classes[r[0]], r[1]))
    return return_list


# get response, return response
def get_response(message, id="000"):
    spell = Speller()  # autocorrect
    corrected_message = spell(message)
    results = predict_class(corrected_message)  # get list of tuples (tag, probability)
    if results:  # if results exist
        while results:  # loop through results
            for intent in intents["intents"]:  # loop through intents
                if intent["tag"] == results[0][0]:  # if tag matches
                    if intent["tag"].lower() == "reiterate":  # if tag is reiterate
                        if context:  # if context exists
                            for tg in intents["intents"]:
                                if (
                                    "context_set" in tg
                                    and tg["context_set"] == context[id]
                                ):
                                    response = random.choice(tg["responses"])
                                    return str(response)
                        else:
                            response = random.choice(intent["responses"])
                            return str(response)
                    if "context_set" in intent and intent["context_set"] != "":
                        context[id] = intent["context_set"]
                    response = random.choice(intent["responses"])
                    return str(response)
            results.pop(0)
    else:  # if no results
        response = "I apologize if my response wasn't what you were looking for. As an AI language model, my knowledge and understanding are limited by the data that I was trained on. If you need more detailed or specific information, I suggest consulting with a human expert or conducting further research online. Please let me know if you have any other questions or if there's anything else I can help you with."
    return str(response)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Epoch 1/300
# 42/42 [==============================] - 2s 7ms/step - loss: 4.8291 - accuracy: 0.0119
# Epoch 2/300
# 42/42 [==============================] - 0s 8ms/step - loss: 4.7649 - accuracy: 0.0310
# Epoch 3/300
# 42/42 [==============================] - 0s 8ms/step - loss: 4.6773 - accuracy: 0.0286
# Epoch 4/300
# 42/42 [==============================] - 0s 6ms/step - loss: 4.5221 - accuracy: 0.0500
# Epoch 5/300
# 42/42 [==============================] - 0s 7ms/step - loss: 4.3285 - accuracy: 0.0881
# Epoch 6/300
# 42/42 [==============================] - 0s 7ms/step - loss: 4.1387 - accuracy: 0.0810
# Epoch 7/300
# 42/42 [==============================] - 0s 12ms/step - loss: 3.9563 - accuracy: 0.0976
# Epoch 8/300
# 42/42 [==============================] - 0s 11ms/step - loss: 3.7106 - accuracy: 0.1548
# Epoch 9/300
# 42/42 [==============================] - 0s 9ms/step - loss: 3.5308 - accuracy: 0.1643
# Epoch 10/300
# 42/42 [==============================] - 0s 7ms/step - loss: 3.2420 - accuracy: 0.2000
# Epoch 11/300
# 42/42 [==============================] - 0s 7ms/step - loss: 2.9466 - accuracy: 0.2690
# Epoch 12/300
# 42/42 [==============================] - 0s 9ms/step - loss: 2.8333 - accuracy: 0.2881
# Epoch 13/300
# 42/42 [==============================] - 0s 6ms/step - loss: 2.6010 - accuracy: 0.3524
# Epoch 14/300
# 42/42 [==============================] - 0s 5ms/step - loss: 2.4440 - accuracy: 0.3714
# Epoch 15/300
# 42/42 [==============================] - 0s 5ms/step - loss: 2.3101 - accuracy: 0.4143
# Epoch 16/300
# 42/42 [==============================] - 0s 6ms/step - loss: 2.1118 - accuracy: 0.4595
# Epoch 17/300
# 42/42 [==============================] - 0s 7ms/step - loss: 1.9824 - accuracy: 0.5071
# Epoch 18/300
# 42/42 [==============================] - 0s 7ms/step - loss: 1.8342 - accuracy: 0.5333
# Epoch 19/300
# 42/42 [==============================] - 0s 7ms/step - loss: 1.6703 - accuracy: 0.5405
# Epoch 20/300
# 42/42 [==============================] - 0s 7ms/step - loss: 1.6439 - accuracy: 0.5690
# Epoch 21/300
# 42/42 [==============================] - 0s 7ms/step - loss: 1.4861 - accuracy: 0.5905
# Epoch 22/300
# 42/42 [==============================] - 0s 8ms/step - loss: 1.4558 - accuracy: 0.6214
# Epoch 23/300
# 42/42 [==============================] - 1s 14ms/step - loss: 1.3821 - accuracy: 0.6048
# Epoch 24/300
# 42/42 [==============================] - 1s 12ms/step - loss: 1.3010 - accuracy: 0.6357
# Epoch 25/300
# 42/42 [==============================] - 0s 10ms/step - loss: 1.2497 - accuracy: 0.6500
# Epoch 26/300
# 42/42 [==============================] - 0s 11ms/step - loss: 1.1671 - accuracy: 0.6714
# Epoch 27/300
# 42/42 [==============================] - 0s 11ms/step - loss: 1.0875 - accuracy: 0.6952
# Epoch 28/300
# 42/42 [==============================] - 0s 9ms/step - loss: 1.0560 - accuracy: 0.7262
# Epoch 29/300
# 42/42 [==============================] - 0s 10ms/step - loss: 1.0642 - accuracy: 0.7000
# Epoch 30/300
# 42/42 [==============================] - 0s 10ms/step - loss: 0.9036 - accuracy: 0.7262
# Epoch 31/300
# 42/42 [==============================] - 1s 14ms/step - loss: 1.0214 - accuracy: 0.6929
# Epoch 32/300
# 42/42 [==============================] - 1s 12ms/step - loss: 0.8815 - accuracy: 0.7476
# Epoch 33/300
# 42/42 [==============================] - 0s 10ms/step - loss: 0.8938 - accuracy: 0.7357
# Epoch 34/300
# 42/42 [==============================] - 0s 11ms/step - loss: 0.7787 - accuracy: 0.8048
# Epoch 35/300
# 42/42 [==============================] - 0s 10ms/step - loss: 0.7562 - accuracy: 0.7738
# Epoch 36/300
# 42/42 [==============================] - 0s 10ms/step - loss: 0.8006 - accuracy: 0.7643
# Epoch 37/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.8070 - accuracy: 0.7643
# Epoch 38/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.6827 - accuracy: 0.7762
# Epoch 39/300
# 42/42 [==============================] - 0s 7ms/step - loss: 0.6567 - accuracy: 0.7976
# Epoch 40/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.6425 - accuracy: 0.8095
# Epoch 41/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.6435 - accuracy: 0.8190
# Epoch 42/300
# 42/42 [==============================] - 0s 7ms/step - loss: 0.6819 - accuracy: 0.8119
# Epoch 43/300
# 42/42 [==============================] - 0s 8ms/step - loss: 0.5774 - accuracy: 0.8238
# Epoch 44/300
# 42/42 [==============================] - 0s 8ms/step - loss: 0.5823 - accuracy: 0.8429
# Epoch 45/300
# 42/42 [==============================] - 0s 7ms/step - loss: 0.5656 - accuracy: 0.8310
# Epoch 46/300
# 42/42 [==============================] - 0s 8ms/step - loss: 0.5715 - accuracy: 0.8333
# Epoch 47/300
# 42/42 [==============================] - 0s 9ms/step - loss: 0.5698 - accuracy: 0.8476
# Epoch 48/300
# 42/42 [==============================] - 0s 8ms/step - loss: 0.5429 - accuracy: 0.8333
# Epoch 49/300
# 42/42 [==============================] - 0s 11ms/step - loss: 0.5336 - accuracy: 0.8405
# Epoch 50/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.5036 - accuracy: 0.8357
# Epoch 51/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.5429 - accuracy: 0.8357
# Epoch 52/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.4918 - accuracy: 0.8714
# Epoch 53/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4258 - accuracy: 0.8762
# Epoch 54/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.5010 - accuracy: 0.8476
# Epoch 55/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4194 - accuracy: 0.8643
# Epoch 56/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4914 - accuracy: 0.8548
# Epoch 57/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4258 - accuracy: 0.8643
# Epoch 58/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4771 - accuracy: 0.8548
# Epoch 59/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3794 - accuracy: 0.8952
# Epoch 60/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3704 - accuracy: 0.8810
# Epoch 61/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4054 - accuracy: 0.8762
# Epoch 62/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4423 - accuracy: 0.8714
# Epoch 63/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4317 - accuracy: 0.8643
# Epoch 64/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4262 - accuracy: 0.8833
# Epoch 65/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3737 - accuracy: 0.8786
# Epoch 66/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4579 - accuracy: 0.8738
# Epoch 67/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4508 - accuracy: 0.8762
# Epoch 68/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3563 - accuracy: 0.8905
# Epoch 69/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3327 - accuracy: 0.8976
# Epoch 70/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2936 - accuracy: 0.9190
# Epoch 71/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4028 - accuracy: 0.8810
# Epoch 72/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3750 - accuracy: 0.8881
# Epoch 73/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3566 - accuracy: 0.8810
# Epoch 74/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3259 - accuracy: 0.9024
# Epoch 75/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4043 - accuracy: 0.8714
# Epoch 76/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3990 - accuracy: 0.8762
# Epoch 77/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3631 - accuracy: 0.8905
# Epoch 78/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3385 - accuracy: 0.8786
# Epoch 79/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3499 - accuracy: 0.8952
# Epoch 80/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.3599 - accuracy: 0.8857
# Epoch 81/300
# 42/42 [==============================] - 0s 7ms/step - loss: 0.3183 - accuracy: 0.9095
# Epoch 82/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2750 - accuracy: 0.9286
# Epoch 83/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.3212 - accuracy: 0.9119
# Epoch 84/300
# 42/42 [==============================] - 0s 11ms/step - loss: 0.3103 - accuracy: 0.9143
# Epoch 85/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.3279 - accuracy: 0.8905
# Epoch 86/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.3974 - accuracy: 0.8857
# Epoch 87/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2833 - accuracy: 0.9119
# Epoch 88/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2734 - accuracy: 0.9095
# Epoch 89/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2829 - accuracy: 0.9143
# Epoch 90/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2601 - accuracy: 0.9167
# Epoch 91/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2585 - accuracy: 0.9143
# Epoch 92/300
# 42/42 [==============================] - 0s 11ms/step - loss: 0.3059 - accuracy: 0.8881
# Epoch 93/300
# 42/42 [==============================] - 0s 10ms/step - loss: 0.2678 - accuracy: 0.9333
# Epoch 94/300
# 42/42 [==============================] - 0s 8ms/step - loss: 0.2525 - accuracy: 0.9238
# Epoch 95/300
# 42/42 [==============================] - 0s 9ms/step - loss: 0.2486 - accuracy: 0.9048
# Epoch 96/300
# 42/42 [==============================] - 0s 11ms/step - loss: 0.2972 - accuracy: 0.9024
# Epoch 97/300
# 42/42 [==============================] - 1s 12ms/step - loss: 0.2675 - accuracy: 0.9167
# Epoch 98/300
# 42/42 [==============================] - 1s 12ms/step - loss: 0.2044 - accuracy: 0.9357
# Epoch 99/300
# 42/42 [==============================] - 0s 10ms/step - loss: 0.2330 - accuracy: 0.9167
# Epoch 100/300
# 42/42 [==============================] - 0s 7ms/step - loss: 0.2174 - accuracy: 0.9286
# Epoch 101/300
# 42/42 [==============================] - 0s 7ms/step - loss: 0.2444 - accuracy: 0.9167
# Epoch 102/300
# 42/42 [==============================] - 0s 7ms/step - loss: 0.2184 - accuracy: 0.9214
# Epoch 103/300
# 42/42 [==============================] - 0s 9ms/step - loss: 0.2836 - accuracy: 0.9238
# Epoch 104/300
# 42/42 [==============================] - 0s 8ms/step - loss: 0.2854 - accuracy: 0.9167
# Epoch 105/300
# 42/42 [==============================] - 0s 7ms/step - loss: 0.2670 - accuracy: 0.9167
# Epoch 106/300
# 42/42 [==============================] - 0s 7ms/step - loss: 0.2580 - accuracy: 0.9262
# Epoch 107/300
# 42/42 [==============================] - 0s 7ms/step - loss: 0.2444 - accuracy: 0.9286
# Epoch 108/300
# 42/42 [==============================] - 0s 7ms/step - loss: 0.2541 - accuracy: 0.9167
# Epoch 109/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1944 - accuracy: 0.9405
# Epoch 110/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2390 - accuracy: 0.9238
# Epoch 111/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2513 - accuracy: 0.9071
# Epoch 112/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2689 - accuracy: 0.9238
# Epoch 113/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2177 - accuracy: 0.9214
# Epoch 114/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2231 - accuracy: 0.9405
# Epoch 115/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1786 - accuracy: 0.9548
# Epoch 116/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2423 - accuracy: 0.9143
# Epoch 117/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2392 - accuracy: 0.9262
# Epoch 118/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2096 - accuracy: 0.9310
# Epoch 119/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2274 - accuracy: 0.9214
# Epoch 120/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1609 - accuracy: 0.9429
# Epoch 121/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1918 - accuracy: 0.9429
# Epoch 122/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2036 - accuracy: 0.9286
# Epoch 123/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2041 - accuracy: 0.9190
# Epoch 124/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2518 - accuracy: 0.9214
# Epoch 125/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2055 - accuracy: 0.9357
# Epoch 126/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2432 - accuracy: 0.9262
# Epoch 127/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1989 - accuracy: 0.9381
# Epoch 128/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2451 - accuracy: 0.9333
# Epoch 129/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2379 - accuracy: 0.9238
# Epoch 130/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1954 - accuracy: 0.9571
# Epoch 131/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1981 - accuracy: 0.9333
# Epoch 132/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1951 - accuracy: 0.9452
# Epoch 133/300
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1973 - accuracy: 0.9286
# Epoch 134/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1713 - accuracy: 0.9571
# Epoch 135/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2335 - accuracy: 0.9262
# Epoch 136/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2013 - accuracy: 0.9238
# Epoch 137/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1791 - accuracy: 0.9333
# Epoch 138/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1917 - accuracy: 0.9357
# Epoch 139/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2276 - accuracy: 0.9310
# Epoch 140/300
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2308 - accuracy: 0.9333
# Epoch 141/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2671 - accuracy: 0.9190
# Epoch 142/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1743 - accuracy: 0.9381
# Epoch 143/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2069 - accuracy: 0.9452
# Epoch 144/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2375 - accuracy: 0.9381
# Epoch 145/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1709 - accuracy: 0.9429
# Epoch 146/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1477 - accuracy: 0.9619
# Epoch 147/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1459 - accuracy: 0.9476
# Epoch 148/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1900 - accuracy: 0.9429
# Epoch 149/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1823 - accuracy: 0.9595
# Epoch 150/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1833 - accuracy: 0.9452
# Epoch 151/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1956 - accuracy: 0.9190
# Epoch 152/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1787 - accuracy: 0.9524
# Epoch 153/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1750 - accuracy: 0.9452
# Epoch 154/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2227 - accuracy: 0.9262
# Epoch 155/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1508 - accuracy: 0.9548
# Epoch 156/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2036 - accuracy: 0.9333
# Epoch 157/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1742 - accuracy: 0.9500
# Epoch 158/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1560 - accuracy: 0.9476
# Epoch 159/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1996 - accuracy: 0.9357
# Epoch 160/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1259 - accuracy: 0.9595
# Epoch 161/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1505 - accuracy: 0.9500
# Epoch 162/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1768 - accuracy: 0.9333
# Epoch 163/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.2297 - accuracy: 0.9119
# Epoch 164/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1999 - accuracy: 0.9357
# Epoch 165/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.2011 - accuracy: 0.9286
# Epoch 166/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1577 - accuracy: 0.9571
# Epoch 167/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1878 - accuracy: 0.9429
# Epoch 168/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1730 - accuracy: 0.9262
# Epoch 169/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1928 - accuracy: 0.9214
# Epoch 170/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1899 - accuracy: 0.9310
# Epoch 171/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1612 - accuracy: 0.9452
# Epoch 172/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1610 - accuracy: 0.9452
# Epoch 173/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.2009 - accuracy: 0.9357
# Epoch 174/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1953 - accuracy: 0.9310
# Epoch 175/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2005 - accuracy: 0.9310
# Epoch 176/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.2752 - accuracy: 0.9167
# Epoch 177/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1578 - accuracy: 0.9571
# Epoch 178/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1775 - accuracy: 0.9429
# Epoch 179/300
# 42/42 [==============================] - 0s 7ms/step - loss: 0.1691 - accuracy: 0.9476
# Epoch 180/300
# 42/42 [==============================] - 0s 7ms/step - loss: 0.1586 - accuracy: 0.9429
# Epoch 181/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1574 - accuracy: 0.9524
# Epoch 182/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1473 - accuracy: 0.9452
# Epoch 183/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1269 - accuracy: 0.9714
# Epoch 184/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1411 - accuracy: 0.9524
# Epoch 185/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1717 - accuracy: 0.9381
# Epoch 186/300
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1295 - accuracy: 0.9571
# Epoch 187/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1599 - accuracy: 0.9524
# Epoch 188/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1494 - accuracy: 0.9524
# Epoch 189/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1324 - accuracy: 0.9548
# Epoch 190/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1868 - accuracy: 0.9381
# Epoch 191/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1412 - accuracy: 0.9548
# Epoch 192/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1499 - accuracy: 0.9548
# Epoch 193/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1143 - accuracy: 0.9571
# Epoch 194/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1306 - accuracy: 0.9619
# Epoch 195/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1760 - accuracy: 0.9524
# Epoch 196/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1427 - accuracy: 0.9619
# Epoch 197/300
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1183 - accuracy: 0.9595
# Epoch 198/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1637 - accuracy: 0.9524
# Epoch 199/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1599 - accuracy: 0.9619
# Epoch 200/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1362 - accuracy: 0.9595
# Epoch 201/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1810 - accuracy: 0.9452
# Epoch 202/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1705 - accuracy: 0.9548
# Epoch 203/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1703 - accuracy: 0.9357
# Epoch 204/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1179 - accuracy: 0.9548
# Epoch 205/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1313 - accuracy: 0.9524
# Epoch 206/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1529 - accuracy: 0.9476
# Epoch 207/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1161 - accuracy: 0.9643
# Epoch 208/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1673 - accuracy: 0.9429
# Epoch 209/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1085 - accuracy: 0.9643
# Epoch 210/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1252 - accuracy: 0.9548
# Epoch 211/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.9643
# Epoch 212/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1420 - accuracy: 0.9524
# Epoch 213/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1740 - accuracy: 0.9500
# Epoch 214/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1541 - accuracy: 0.9500
# Epoch 215/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1461 - accuracy: 0.9476
# Epoch 216/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1466 - accuracy: 0.9500
# Epoch 217/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1721 - accuracy: 0.9524
# Epoch 218/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1867 - accuracy: 0.9452
# Epoch 219/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1482 - accuracy: 0.9548
# Epoch 220/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1725 - accuracy: 0.9524
# Epoch 221/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1657 - accuracy: 0.9405
# Epoch 222/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1519 - accuracy: 0.9500
# Epoch 223/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1875 - accuracy: 0.9405
# Epoch 224/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1449 - accuracy: 0.9500
# Epoch 225/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1618 - accuracy: 0.9548
# Epoch 226/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1557 - accuracy: 0.9500
# Epoch 227/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1672 - accuracy: 0.9548
# Epoch 228/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1644 - accuracy: 0.9476
# Epoch 229/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1479 - accuracy: 0.9500
# Epoch 230/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1065 - accuracy: 0.9738
# Epoch 231/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1263 - accuracy: 0.9595
# Epoch 232/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1935 - accuracy: 0.9405
# Epoch 233/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1507 - accuracy: 0.9548
# Epoch 234/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1468 - accuracy: 0.9524
# Epoch 235/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1643 - accuracy: 0.9476
# Epoch 236/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0942 - accuracy: 0.9595
# Epoch 237/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1367 - accuracy: 0.9619
# Epoch 238/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0881 - accuracy: 0.9738
# Epoch 239/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1613 - accuracy: 0.9571
# Epoch 240/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1217 - accuracy: 0.9548
# Epoch 241/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1575 - accuracy: 0.9667
# Epoch 242/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1450 - accuracy: 0.9595
# Epoch 243/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1659 - accuracy: 0.9381
# Epoch 244/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1314 - accuracy: 0.9548
# Epoch 245/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1370 - accuracy: 0.9643
# Epoch 246/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.9571
# Epoch 247/300
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1010 - accuracy: 0.9595
# Epoch 248/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1201 - accuracy: 0.9619
# Epoch 249/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1171 - accuracy: 0.9619
# Epoch 250/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1551 - accuracy: 0.9357
# Epoch 251/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1691 - accuracy: 0.9476
# Epoch 252/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1662 - accuracy: 0.9500
# Epoch 253/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1187 - accuracy: 0.9595
# Epoch 254/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1380 - accuracy: 0.9619
# Epoch 255/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1695 - accuracy: 0.9524
# Epoch 256/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1404 - accuracy: 0.9595
# Epoch 257/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0910 - accuracy: 0.9619
# Epoch 258/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1507 - accuracy: 0.9524
# Epoch 259/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1716 - accuracy: 0.9381
# Epoch 260/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1084 - accuracy: 0.9548
# Epoch 261/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1182 - accuracy: 0.9643
# Epoch 262/300
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0770 - accuracy: 0.9762
# Epoch 263/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1511 - accuracy: 0.9452
# Epoch 264/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1192 - accuracy: 0.9571
# Epoch 265/300
# 42/42 [==============================] - 0s 7ms/step - loss: 0.1498 - accuracy: 0.9595
# Epoch 266/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1153 - accuracy: 0.9571
# Epoch 267/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1255 - accuracy: 0.9667
# Epoch 268/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1724 - accuracy: 0.9500
# Epoch 269/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1817 - accuracy: 0.9524
# Epoch 270/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1498 - accuracy: 0.9381
# Epoch 271/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1094 - accuracy: 0.9619
# Epoch 272/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1615 - accuracy: 0.9452
# Epoch 273/300
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0871 - accuracy: 0.9762
# Epoch 274/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1139 - accuracy: 0.9667
# Epoch 275/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1211 - accuracy: 0.9548
# Epoch 276/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1468 - accuracy: 0.9571
# Epoch 277/300
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1359 - accuracy: 0.9595
# Epoch 278/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1295 - accuracy: 0.9595
# Epoch 279/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1282 - accuracy: 0.9500
# Epoch 280/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1351 - accuracy: 0.9524
# Epoch 281/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1379 - accuracy: 0.9500
# Epoch 282/300
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1739 - accuracy: 0.9405
# Epoch 283/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1263 - accuracy: 0.9452
# Epoch 284/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1682 - accuracy: 0.9524
# Epoch 285/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.9667
# Epoch 286/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1408 - accuracy: 0.9476
# Epoch 287/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1162 - accuracy: 0.9571
# Epoch 288/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1008 - accuracy: 0.9786
# Epoch 289/300
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2090 - accuracy: 0.9452
# Epoch 290/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1296 - accuracy: 0.9548
# Epoch 291/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0898 - accuracy: 0.9619
# Epoch 292/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1127 - accuracy: 0.9619
# Epoch 293/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2084 - accuracy: 0.9238
# Epoch 294/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1315 - accuracy: 0.9524
# Epoch 295/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1473 - accuracy: 0.9524
# Epoch 296/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1317 - accuracy: 0.9595
# Epoch 297/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1056 - accuracy: 0.9619
# Epoch 298/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1440 - accuracy: 0.9619
# Epoch 299/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1081 - accuracy: 0.9643
# Epoch 300/300
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1192 - accuracy: 0.9595
# Done
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
    count=0
    while count<5:
      message = input()
      response = get_response(message)
      print(response)
      count+=1
# Out:
# Hello
# 1/1 [==============================] - 0s 27ms/step
# Hi there. What brings you here today?
# Good Morning
# 1/1 [==============================] - 0s 19ms/step
# Good morning. I hope you had a good night's sleep. How are you feeling today?
# Fine
# 1/1 [==============================] - 0s 20ms/step
# How were you feeling last week?
# Sad
# 1/1 [==============================] - 0s 20ms/step
# How long have you been feeling this way?
# 3 days
# 1/1 [==============================] - 0s 20ms/step
# What do you think is the reason behind this?
